# %%
import sys
import matplotlib.pyplot as plt
import os
script_path = os.path.abspath("../../../Library/python/cebra_analysis_helpers")
if script_path not in sys.path:
    sys.path.append(script_path)
import cebra_analysis_helpers
import os
import random
import pickle

# global variables for videos
social_foraging_data_path =  '../../../data/neural/'
output_dir = f"../../../data/gridsearch_results/"
trial_type_to_correct_ports = {0:"north_east",
                               1:"east_south",
                               2:"south_west",
                               3:"west_north",
                               4:"north_south",
                               5:"east_west"}
zone_to_direction = {1:"north", 2:"east", 3:"south", 4:"west"}
direction_to_zone = {"north":1, "east":2, "south":3, "west":4}
direction_to_degrees = {"south":[45,135], "east": [315,45], "north": [225,315], "west": [135,225]}
mouse_id = "73"

# set up gpu
import torch
device_id = 0
print("Cuda available",torch.cuda.is_available())
print("Number of GPUs available",torch.cuda.device_count())
print("GPU name",torch.cuda.get_device_name(device_id))
torch.cuda.set_device(device_id)
if torch.cuda.is_available():
    current_device = torch.cuda.current_device()
    print(f"Using GPU: {torch.cuda.get_device_name(current_device)} (Device {current_device})")
else:
    print("CUDA is not available, running on CPU.")

# load the neural and behavioral data
skip_it_load_it = True
load_path = "../../../data/demo_tmp_save/trueYC073_data_each_session.pkl"
if not skip_it_load_it:
    mouse_and_date_list, neural_data_list, conditions_dict_list, indices_of_trials_each_frame_list, m_str = cebra_analysis_helpers.get_neural_and_behavioral_data_dict(social_foraging_data_path,
                                                                                                                                                                    mouse_id, 
                                                                                                                                                                    output_dir = "../../../data/demo_tmp_save/")
else:
    with open(load_path, 'rb') as f:
        neural_and_behavioral_data_dict =  pickle.load(f)
        mouse_and_date_list = neural_and_behavioral_data_dict["mouse_and_date_list"]
        neural_data_list = neural_and_behavioral_data_dict["neural_data_list"]
        conditions_dict_list = neural_and_behavioral_data_dict["conditions_dict_list"]
        indices_of_trials_each_frame_list = neural_and_behavioral_data_dict["indices_of_trials_each_frame_list"]
        m_str = f"YC0{mouse_id}"

# sample different grids of the gridsearch
for i in range(100):
    conditional = random.sample(["delta"],1)[0]
    time_offset =  random.sample([1],1)[0]
    test_size = 0.2
    output_dims = 3
    temperature_mode = random.sample(["constant"],1)[0]
    temperature = random.sample([0.1,0.2,0.5,1,1.5,2],1)[0]
    max_iter = 10#random.sample([1000,2000,5000,10000,20000],1)[0]
    num_hidden_units = random.sample([16,32,64,128],1)[0]
    output_dims = 3
    lr = random.sample([0.0003],1)[0]
    batch_size = random.sample([256,512,1024],1)[0]
    for approach in ["noRZ_ITI+T_ByT", "noRZ_ITI+T_ByT+shift0.5"]:  
        for behavior in ["angle", "distance"]:
            cebra_analysis_helpers.run_single_grid(output_dir,mouse_and_date_list, neural_data_list, conditions_dict_list, indices_of_trials_each_frame_list,
                            m_str, batch_size,time_offset,temperature_mode,temperature,max_iter,num_hidden_units,output_dims,lr,
                            behavior,approach, conditional, test_size,  tmux_session_name = mouse_id, device_id = device_id)
# Out:
# Cuda available True
# Number of GPUs available 1
# GPU name NVIDIA GeForce RTX 4070 Ti SUPER
# Using GPU: NVIDIA GeForce RTX 4070 Ti SUPER (Device 0)
# starting ../../../data/gridsearch_results/demo_YC073_bs256_tmp1.5_Miter10_h16_lr3e-4/angle_noRZ_ITI+T_ByT_73/
# pos: -0.3699 neg:  7.8880 total:  7.5181 temperature:  1.5000: 100%|█████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 12.93it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs256_tmp1.5_Miter10_h16_lr3e-4/distance_noRZ_ITI+T_ByT_73/
# pos: -0.0519 neg:  7.6168 total:  7.5649 temperature:  1.5000: 100%|█████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 16.13it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs256_tmp1.5_Miter10_h16_lr3e-4/angle_noRZ_ITI+T_ByT+shift0.5_73/
# pos: -0.2625 neg:  7.7960 total:  7.5335 temperature:  1.5000: 100%|█████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 13.46it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs256_tmp1.5_Miter10_h16_lr3e-4/distance_noRZ_ITI+T_ByT+shift0.5_73/
# pos: -0.1025 neg:  7.6508 total:  7.5482 temperature:  1.5000: 100%|█████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 12.37it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs256_tmp1_Miter10_h16_lr3e-4/angle_noRZ_ITI+T_ByT_73/
# pos: -0.4655 neg:  8.0458 total:  7.5804 temperature:  1.0000: 100%|█████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 15.62it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs256_tmp1_Miter10_h16_lr3e-4/distance_noRZ_ITI+T_ByT_73/
# pos: -0.3613 neg:  7.9395 total:  7.5783 temperature:  1.0000: 100%|█████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 14.65it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs256_tmp1_Miter10_h16_lr3e-4/angle_noRZ_ITI+T_ByT+shift0.5_73/
# pos: -0.0374 neg:  7.6925 total:  7.6551 temperature:  1.0000: 100%|█████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 12.92it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs256_tmp1_Miter10_h16_lr3e-4/distance_noRZ_ITI+T_ByT+shift0.5_73/
# pos: -0.1567 neg:  7.7915 total:  7.6348 temperature:  1.0000: 100%|█████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 13.12it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs256_tmp0.5_Miter10_h16_lr3e-4/angle_noRZ_ITI+T_ByT_73/
# pos: -0.7935 neg:  8.6293 total:  7.8358 temperature:  0.5000: 100%|█████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 13.32it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs256_tmp0.5_Miter10_h16_lr3e-4/distance_noRZ_ITI+T_ByT_73/
# pos: -0.5008 neg:  8.4335 total:  7.9327 temperature:  0.5000: 100%|█████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 12.91it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs256_tmp0.5_Miter10_h16_lr3e-4/angle_noRZ_ITI+T_ByT+shift0.5_73/
# pos: -0.5023 neg:  8.4855 total:  7.9832 temperature:  0.5000: 100%|█████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 15.44it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs256_tmp0.5_Miter10_h16_lr3e-4/distance_noRZ_ITI+T_ByT+shift0.5_73/
# pos: -0.6351 neg:  8.5303 total:  7.8952 temperature:  0.5000: 100%|█████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 14.98it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs1024_tmp0.2_Miter10_h32_lr3e-4/angle_noRZ_ITI+T_ByT_73/
# pos: -4.4288 neg:  13.4001 total:  8.9713 temperature:  0.2000: 100%|████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:01<00:00,  6.61it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs1024_tmp0.2_Miter10_h32_lr3e-4/distance_noRZ_ITI+T_ByT_73/
# pos: -4.0889 neg:  13.2122 total:  9.1232 temperature:  0.2000: 100%|████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 12.06it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs1024_tmp0.2_Miter10_h32_lr3e-4/angle_noRZ_ITI+T_ByT+shift0.5_73/
# pos: -3.1019 neg:  12.7494 total:  9.6476 temperature:  0.2000: 100%|████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 11.97it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs1024_tmp0.2_Miter10_h32_lr3e-4/distance_noRZ_ITI+T_ByT+shift0.5_73/
# pos: -2.0444 neg:  12.7072 total:  10.6628 temperature:  0.2000: 100%|███████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 11.49it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs1024_tmp0.1_Miter10_h32_lr3e-4/angle_noRZ_ITI+T_ByT_73/
# pos: -5.7499 neg:  17.5317 total:  11.7818 temperature:  0.1000: 100%|███████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 11.91it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs1024_tmp0.1_Miter10_h32_lr3e-4/distance_noRZ_ITI+T_ByT_73/
# pos: -4.2414 neg:  17.4224 total:  13.1809 temperature:  0.1000: 100%|███████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 11.98it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs1024_tmp0.1_Miter10_h32_lr3e-4/angle_noRZ_ITI+T_ByT+shift0.5_73/
# pos: -5.3335 neg:  17.7010 total:  12.3675 temperature:  0.1000: 100%|███████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 11.25it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs1024_tmp0.1_Miter10_h32_lr3e-4/distance_noRZ_ITI+T_ByT+shift0.5_73/
# pos: -8.3546 neg:  17.9026 total:  9.5480 temperature:  0.1000: 100%|████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 11.53it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs256_tmp2_Miter10_h128_lr3e-4/angle_noRZ_ITI+T_ByT_73/
# pos: -0.4052 neg:  7.8993 total:  7.4941 temperature:  2.0000: 100%|█████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 13.95it/s]
# C:\Users\51058\.conda\envs\cebra\Lib\site-packages\cebra\integrations\matplotlib.py:69: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   self.fig = plt.figure(figsize=figsize, dpi=dpi)
# starting ../../../data/gridsearch_results/demo_YC073_bs256_tmp2_Miter10_h128_lr3e-4/distance_noRZ_ITI+T_ByT_73/
# pos: -0.4695 neg:  7.9591 total:  7.4895 temperature:  2.0000: 100%|█████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 14.59it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs256_tmp2_Miter10_h128_lr3e-4/angle_noRZ_ITI+T_ByT+shift0.5_73/
# pos: -0.4764 neg:  7.9669 total:  7.4906 temperature:  2.0000: 100%|█████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 13.16it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs256_tmp2_Miter10_h128_lr3e-4/distance_noRZ_ITI+T_ByT+shift0.5_73/
# pos: -0.4425 neg:  7.9344 total:  7.4918 temperature:  2.0000: 100%|█████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 15.26it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs512_tmp0.1_Miter10_h16_lr3e-4/angle_noRZ_ITI+T_ByT_73/
# pos: -5.3053 neg:  16.9776 total:  11.6723 temperature:  0.1000: 100%|███████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 16.49it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs512_tmp0.1_Miter10_h16_lr3e-4/distance_noRZ_ITI+T_ByT_73/
# pos: -3.0461 neg:  16.5632 total:  13.5171 temperature:  0.1000: 100%|███████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 13.43it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs512_tmp0.1_Miter10_h16_lr3e-4/angle_noRZ_ITI+T_ByT+shift0.5_73/
# pos: -3.3508 neg:  16.5159 total:  13.1651 temperature:  0.1000: 100%|███████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 14.03it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs512_tmp0.1_Miter10_h16_lr3e-4/distance_noRZ_ITI+T_ByT+shift0.5_73/
# pos: -2.8268 neg:  16.3724 total:  13.5456 temperature:  0.1000: 100%|███████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 15.78it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs1024_tmp2_Miter10_h128_lr3e-4/angle_noRZ_ITI+T_ByT_73/
# pos: -0.4624 neg:  9.3393 total:  8.8769 temperature:  2.0000: 100%|█████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 13.25it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs1024_tmp2_Miter10_h128_lr3e-4/distance_noRZ_ITI+T_ByT_73/
# pos: -0.4522 neg:  9.3274 total:  8.8751 temperature:  2.0000: 100%|█████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 12.11it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs1024_tmp2_Miter10_h128_lr3e-4/angle_noRZ_ITI+T_ByT+shift0.5_73/
# pos: -0.4706 neg:  9.3472 total:  8.8766 temperature:  2.0000: 100%|█████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 14.89it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs1024_tmp2_Miter10_h128_lr3e-4/distance_noRZ_ITI+T_ByT+shift0.5_73/
# pos: -0.4515 neg:  9.3279 total:  8.8764 temperature:  2.0000: 100%|█████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 14.40it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs512_tmp2_Miter10_h64_lr3e-4/angle_noRZ_ITI+T_ByT_73/
# pos: -0.2545 neg:  8.4520 total:  8.1976 temperature:  2.0000: 100%|█████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 13.83it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs512_tmp2_Miter10_h64_lr3e-4/distance_noRZ_ITI+T_ByT_73/
# pos: -0.3875 neg:  8.5754 total:  8.1879 temperature:  2.0000: 100%|█████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 14.57it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs512_tmp2_Miter10_h64_lr3e-4/angle_noRZ_ITI+T_ByT+shift0.5_73/
# pos: -0.4673 neg:  8.6507 total:  8.1835 temperature:  2.0000: 100%|█████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 14.93it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs512_tmp2_Miter10_h64_lr3e-4/distance_noRZ_ITI+T_ByT+shift0.5_73/
# pos: -0.0485 neg:  8.2634 total:  8.2149 temperature:  2.0000: 100%|█████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 15.72it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs1024_tmp0.5_Miter10_h32_lr3e-4/angle_noRZ_ITI+T_ByT_73/
# pos: -0.8042 neg:  10.0211 total:  9.2169 temperature:  0.5000: 100%|████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 11.01it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs1024_tmp0.5_Miter10_h32_lr3e-4/distance_noRZ_ITI+T_ByT_73/
# pos: -1.1910 neg:  10.2752 total:  9.0842 temperature:  0.5000: 100%|████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 11.31it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs1024_tmp0.5_Miter10_h32_lr3e-4/angle_noRZ_ITI+T_ByT+shift0.5_73/
# pos: -1.6668 neg:  10.5764 total:  8.9096 temperature:  0.5000: 100%|████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 11.47it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs1024_tmp0.5_Miter10_h32_lr3e-4/distance_noRZ_ITI+T_ByT+shift0.5_73/
# pos: -0.7602 neg:  9.9590 total:  9.1987 temperature:  0.5000: 100%|█████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 11.30it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs512_tmp1_Miter10_h32_lr3e-4/angle_noRZ_ITI+T_ByT_73/
# pos: -0.4540 neg:  8.7153 total:  8.2613 temperature:  1.0000: 100%|█████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 14.37it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs512_tmp1_Miter10_h32_lr3e-4/distance_noRZ_ITI+T_ByT_73/
# pos: -0.6050 neg:  8.8349 total:  8.2299 temperature:  1.0000: 100%|█████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 15.02it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs512_tmp1_Miter10_h32_lr3e-4/angle_noRZ_ITI+T_ByT+shift0.5_73/
# pos: -0.1606 neg:  8.4907 total:  8.3301 temperature:  1.0000: 100%|█████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 15.67it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs512_tmp1_Miter10_h32_lr3e-4/distance_noRZ_ITI+T_ByT+shift0.5_73/
# pos: -0.5801 neg:  8.8204 total:  8.2403 temperature:  1.0000: 100%|█████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 14.64it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs256_tmp0.2_Miter10_h128_lr3e-4/angle_noRZ_ITI+T_ByT_73/
# pos: -4.8377 neg:  12.3351 total:  7.4975 temperature:  0.2000: 100%|████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 14.01it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs256_tmp0.2_Miter10_h128_lr3e-4/distance_noRZ_ITI+T_ByT_73/
# pos: -4.8369 neg:  12.3362 total:  7.4993 temperature:  0.2000: 100%|████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 14.93it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs256_tmp0.2_Miter10_h128_lr3e-4/angle_noRZ_ITI+T_ByT+shift0.5_73/
# pos: -4.7931 neg:  12.2991 total:  7.5061 temperature:  0.2000: 100%|████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 15.52it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs256_tmp0.2_Miter10_h128_lr3e-4/distance_noRZ_ITI+T_ByT+shift0.5_73/
# pos: -4.9054 neg:  12.3983 total:  7.4928 temperature:  0.2000: 100%|████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 13.28it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs512_tmp2_Miter10_h16_lr3e-4/angle_noRZ_ITI+T_ByT_73/
# pos: -0.0871 neg:  8.3052 total:  8.2181 temperature:  2.0000: 100%|█████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 12.20it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs512_tmp2_Miter10_h16_lr3e-4/distance_noRZ_ITI+T_ByT_73/
# pos: -0.1100 neg:  8.3307 total:  8.2207 temperature:  2.0000: 100%|█████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 14.65it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs512_tmp2_Miter10_h16_lr3e-4/angle_noRZ_ITI+T_ByT+shift0.5_73/
# pos: -0.0580 neg:  8.2809 total:  8.2229 temperature:  2.0000: 100%|█████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 14.64it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs512_tmp2_Miter10_h16_lr3e-4/distance_noRZ_ITI+T_ByT+shift0.5_73/
# pos: -0.1526 neg:  8.3659 total:  8.2133 temperature:  2.0000: 100%|█████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 15.90it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs1024_tmp0.5_Miter10_h128_lr3e-4/angle_noRZ_ITI+T_ByT_73/
# pos: -1.9468 neg:  10.8253 total:  8.8786 temperature:  0.5000: 100%|████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 12.38it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs1024_tmp0.5_Miter10_h128_lr3e-4/distance_noRZ_ITI+T_ByT_73/
# pos: -1.8666 neg:  10.7499 total:  8.8833 temperature:  0.5000: 100%|████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 13.41it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs1024_tmp0.5_Miter10_h128_lr3e-4/angle_noRZ_ITI+T_ByT+shift0.5_73/
# pos: -1.8830 neg:  10.7640 total:  8.8810 temperature:  0.5000: 100%|████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 13.98it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs1024_tmp0.5_Miter10_h128_lr3e-4/distance_noRZ_ITI+T_ByT+shift0.5_73/
# pos: -1.9169 neg:  10.7968 total:  8.8799 temperature:  0.5000: 100%|████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 13.28it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs256_tmp2_Miter10_h128_lr3e-4/angle_noRZ_ITI+T_ByT_73/
# already exists at ../../../data/gridsearch_results/demo_YC073_bs256_tmp2_Miter10_h128_lr3e-4/angle_noRZ_ITI+T_ByT_73/
# starting ../../../data/gridsearch_results/demo_YC073_bs256_tmp2_Miter10_h128_lr3e-4/distance_noRZ_ITI+T_ByT_73/
# already exists at ../../../data/gridsearch_results/demo_YC073_bs256_tmp2_Miter10_h128_lr3e-4/distance_noRZ_ITI+T_ByT_73/
# starting ../../../data/gridsearch_results/demo_YC073_bs256_tmp2_Miter10_h128_lr3e-4/angle_noRZ_ITI+T_ByT+shift0.5_73/
# already exists at ../../../data/gridsearch_results/demo_YC073_bs256_tmp2_Miter10_h128_lr3e-4/angle_noRZ_ITI+T_ByT+shift0.5_73/
# starting ../../../data/gridsearch_results/demo_YC073_bs256_tmp2_Miter10_h128_lr3e-4/distance_noRZ_ITI+T_ByT+shift0.5_73/
# already exists at ../../../data/gridsearch_results/demo_YC073_bs256_tmp2_Miter10_h128_lr3e-4/distance_noRZ_ITI+T_ByT+shift0.5_73/
# starting ../../../data/gridsearch_results/demo_YC073_bs512_tmp0.5_Miter10_h16_lr3e-4/angle_noRZ_ITI+T_ByT_73/
# pos: -0.9051 neg:  9.3842 total:  8.4791 temperature:  0.5000: 100%|█████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 16.78it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs512_tmp0.5_Miter10_h16_lr3e-4/distance_noRZ_ITI+T_ByT_73/
# pos: -0.4446 neg:  9.1096 total:  8.6650 temperature:  0.5000: 100%|█████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 13.70it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs512_tmp0.5_Miter10_h16_lr3e-4/angle_noRZ_ITI+T_ByT+shift0.5_73/
# pos: -0.4126 neg:  9.1345 total:  8.7219 temperature:  0.5000: 100%|█████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 14.61it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs512_tmp0.5_Miter10_h16_lr3e-4/distance_noRZ_ITI+T_ByT+shift0.5_73/
# pos: -0.6625 neg:  9.2567 total:  8.5941 temperature:  0.5000: 100%|█████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 14.08it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs1024_tmp2_Miter10_h16_lr3e-4/angle_noRZ_ITI+T_ByT_73/
# pos: -0.0898 neg:  9.0009 total:  8.9111 temperature:  2.0000: 100%|█████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 12.62it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs1024_tmp2_Miter10_h16_lr3e-4/distance_noRZ_ITI+T_ByT_73/
# pos: -0.0998 neg:  9.0062 total:  8.9064 temperature:  2.0000: 100%|█████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 13.62it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs1024_tmp2_Miter10_h16_lr3e-4/angle_noRZ_ITI+T_ByT+shift0.5_73/
# pos: -0.1875 neg:  9.0887 total:  8.9011 temperature:  2.0000: 100%|█████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 14.32it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs1024_tmp2_Miter10_h16_lr3e-4/distance_noRZ_ITI+T_ByT+shift0.5_73/
# pos: -0.1435 neg:  9.0493 total:  8.9059 temperature:  2.0000: 100%|█████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 14.79it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs256_tmp0.2_Miter10_h16_lr3e-4/angle_noRZ_ITI+T_ByT_73/
# pos: -1.7314 neg:  11.0261 total:  9.2947 temperature:  0.2000: 100%|████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 15.44it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs256_tmp0.2_Miter10_h16_lr3e-4/distance_noRZ_ITI+T_ByT_73/
# pos: -0.5321 neg:  10.7865 total:  10.2544 temperature:  0.2000: 100%|███████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 17.15it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs256_tmp0.2_Miter10_h16_lr3e-4/angle_noRZ_ITI+T_ByT+shift0.5_73/
# pos: -3.9136 neg:  11.7086 total:  7.7950 temperature:  0.2000: 100%|████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 16.01it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs256_tmp0.2_Miter10_h16_lr3e-4/distance_noRZ_ITI+T_ByT+shift0.5_73/
# pos: -2.3324 neg:  11.3094 total:  8.9770 temperature:  0.2000: 100%|████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 17.79it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs1024_tmp1_Miter10_h128_lr3e-4/angle_noRZ_ITI+T_ByT_73/
# pos: -0.9607 neg:  9.8385 total:  8.8778 temperature:  1.0000: 100%|█████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 11.05it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs1024_tmp1_Miter10_h128_lr3e-4/distance_noRZ_ITI+T_ByT_73/
# pos: -0.9615 neg:  9.8380 total:  8.8765 temperature:  1.0000: 100%|█████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 13.50it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs1024_tmp1_Miter10_h128_lr3e-4/angle_noRZ_ITI+T_ByT+shift0.5_73/
# pos: -0.8840 neg:  9.7684 total:  8.8843 temperature:  1.0000: 100%|█████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 13.36it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs1024_tmp1_Miter10_h128_lr3e-4/distance_noRZ_ITI+T_ByT+shift0.5_73/
# pos: -0.5245 neg:  9.4580 total:  8.9335 temperature:  1.0000: 100%|█████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 13.53it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs512_tmp1_Miter10_h16_lr3e-4/angle_noRZ_ITI+T_ByT_73/
# pos: -0.2988 neg:  8.5988 total:  8.3000 temperature:  1.0000: 100%|█████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 14.83it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs512_tmp1_Miter10_h16_lr3e-4/distance_noRZ_ITI+T_ByT_73/
# pos: -0.0113 neg:  8.3707 total:  8.3594 temperature:  1.0000: 100%|█████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 15.62it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs512_tmp1_Miter10_h16_lr3e-4/angle_noRZ_ITI+T_ByT+shift0.5_73/
# pos: -0.2182 neg:  8.5327 total:  8.3145 temperature:  1.0000: 100%|█████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 15.02it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs512_tmp1_Miter10_h16_lr3e-4/distance_noRZ_ITI+T_ByT+shift0.5_73/
# pos: -0.6465 neg:  8.8691 total:  8.2226 temperature:  1.0000: 100%|█████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 13.95it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs256_tmp0.1_Miter10_h32_lr3e-4/angle_noRZ_ITI+T_ByT_73/
# pos: -9.2245 neg:  16.8918 total:  7.6673 temperature:  0.1000: 100%|████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 15.60it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs256_tmp0.1_Miter10_h32_lr3e-4/distance_noRZ_ITI+T_ByT_73/
# pos: -8.6024 neg:  16.5865 total:  7.9842 temperature:  0.1000: 100%|████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 15.57it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs256_tmp0.1_Miter10_h32_lr3e-4/angle_noRZ_ITI+T_ByT+shift0.5_73/
# pos: -5.2166 neg:  15.8923 total:  10.6758 temperature:  0.1000: 100%|███████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 13.96it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs256_tmp0.1_Miter10_h32_lr3e-4/distance_noRZ_ITI+T_ByT+shift0.5_73/
# pos: -5.9514 neg:  16.1726 total:  10.2212 temperature:  0.1000: 100%|███████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 14.11it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs512_tmp0.5_Miter10_h64_lr3e-4/angle_noRZ_ITI+T_ByT_73/
# pos: -1.9374 neg:  10.1222 total:  8.1848 temperature:  0.5000: 100%|████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 11.80it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs512_tmp0.5_Miter10_h64_lr3e-4/distance_noRZ_ITI+T_ByT_73/
# pos: -1.0353 neg:  9.4887 total:  8.4534 temperature:  0.5000: 100%|█████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 14.49it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs512_tmp0.5_Miter10_h64_lr3e-4/angle_noRZ_ITI+T_ByT+shift0.5_73/
# pos: -1.9131 neg:  10.0991 total:  8.1860 temperature:  0.5000: 100%|████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 16.93it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs512_tmp0.5_Miter10_h64_lr3e-4/distance_noRZ_ITI+T_ByT+shift0.5_73/
# pos: -1.7691 neg:  9.9665 total:  8.1974 temperature:  0.5000: 100%|█████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 13.70it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs512_tmp1_Miter10_h64_lr3e-4/angle_noRZ_ITI+T_ByT_73/
# pos: -0.9759 neg:  9.1606 total:  8.1847 temperature:  1.0000: 100%|█████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 14.01it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs512_tmp1_Miter10_h64_lr3e-4/distance_noRZ_ITI+T_ByT_73/
# pos: -0.7949 neg:  8.9881 total:  8.1933 temperature:  1.0000: 100%|█████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 15.52it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs512_tmp1_Miter10_h64_lr3e-4/angle_noRZ_ITI+T_ByT+shift0.5_73/
# pos: -0.8008 neg:  8.9953 total:  8.1945 temperature:  1.0000: 100%|█████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 14.99it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs512_tmp1_Miter10_h64_lr3e-4/distance_noRZ_ITI+T_ByT+shift0.5_73/
# pos: -0.8791 neg:  9.0672 total:  8.1882 temperature:  1.0000: 100%|█████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 16.27it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs512_tmp0.2_Miter10_h32_lr3e-4/angle_noRZ_ITI+T_ByT_73/
# pos: -3.2729 neg:  12.3449 total:  9.0720 temperature:  0.2000: 100%|████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 14.85it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs512_tmp0.2_Miter10_h32_lr3e-4/distance_noRZ_ITI+T_ByT_73/
# pos: -0.2405 neg:  11.3856 total:  11.1452 temperature:  0.2000: 100%|███████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 15.78it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs512_tmp0.2_Miter10_h32_lr3e-4/angle_noRZ_ITI+T_ByT+shift0.5_73/
# pos: -4.2196 neg:  12.5781 total:  8.3585 temperature:  0.2000: 100%|████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 16.92it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs512_tmp0.2_Miter10_h32_lr3e-4/distance_noRZ_ITI+T_ByT+shift0.5_73/
# pos: -3.3862 neg:  12.3041 total:  8.9179 temperature:  0.2000: 100%|████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 16.13it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs1024_tmp0.1_Miter10_h128_lr3e-4/angle_noRZ_ITI+T_ByT_73/
# pos: -9.6397 neg:  18.5537 total:  8.9141 temperature:  0.1000: 100%|████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 12.80it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs1024_tmp0.1_Miter10_h128_lr3e-4/distance_noRZ_ITI+T_ByT_73/
# pos: -9.6482 neg:  18.5567 total:  8.9085 temperature:  0.1000: 100%|████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 13.01it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs1024_tmp0.1_Miter10_h128_lr3e-4/angle_noRZ_ITI+T_ByT+shift0.5_73/
# pos: -9.5137 neg:  18.4604 total:  8.9467 temperature:  0.1000: 100%|████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 12.84it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs1024_tmp0.1_Miter10_h128_lr3e-4/distance_noRZ_ITI+T_ByT+shift0.5_73/
# pos: -9.7395 neg:  18.6365 total:  8.8970 temperature:  0.1000: 100%|████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 12.35it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs1024_tmp2_Miter10_h128_lr3e-4/angle_noRZ_ITI+T_ByT_73/
# already exists at ../../../data/gridsearch_results/demo_YC073_bs1024_tmp2_Miter10_h128_lr3e-4/angle_noRZ_ITI+T_ByT_73/
# starting ../../../data/gridsearch_results/demo_YC073_bs1024_tmp2_Miter10_h128_lr3e-4/distance_noRZ_ITI+T_ByT_73/
# already exists at ../../../data/gridsearch_results/demo_YC073_bs1024_tmp2_Miter10_h128_lr3e-4/distance_noRZ_ITI+T_ByT_73/
# starting ../../../data/gridsearch_results/demo_YC073_bs1024_tmp2_Miter10_h128_lr3e-4/angle_noRZ_ITI+T_ByT+shift0.5_73/
# already exists at ../../../data/gridsearch_results/demo_YC073_bs1024_tmp2_Miter10_h128_lr3e-4/angle_noRZ_ITI+T_ByT+shift0.5_73/
# starting ../../../data/gridsearch_results/demo_YC073_bs1024_tmp2_Miter10_h128_lr3e-4/distance_noRZ_ITI+T_ByT+shift0.5_73/
# already exists at ../../../data/gridsearch_results/demo_YC073_bs1024_tmp2_Miter10_h128_lr3e-4/distance_noRZ_ITI+T_ByT+shift0.5_73/
# starting ../../../data/gridsearch_results/demo_YC073_bs512_tmp0.5_Miter10_h128_lr3e-4/angle_noRZ_ITI+T_ByT_73/
# pos: -1.9139 neg:  10.1024 total:  8.1885 temperature:  0.5000: 100%|████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 13.33it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs512_tmp0.5_Miter10_h128_lr3e-4/distance_noRZ_ITI+T_ByT_73/
# pos: -1.8942 neg:  10.0808 total:  8.1866 temperature:  0.5000: 100%|████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 15.48it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs512_tmp0.5_Miter10_h128_lr3e-4/angle_noRZ_ITI+T_ByT+shift0.5_73/
# pos: -1.9111 neg:  10.0963 total:  8.1852 temperature:  0.5000: 100%|████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 16.39it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs512_tmp0.5_Miter10_h128_lr3e-4/distance_noRZ_ITI+T_ByT+shift0.5_73/
# pos: -1.9038 neg:  10.0897 total:  8.1859 temperature:  0.5000: 100%|████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 15.45it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs256_tmp0.2_Miter10_h32_lr3e-4/angle_noRZ_ITI+T_ByT_73/
# pos: -2.2701 neg:  11.1394 total:  8.8693 temperature:  0.2000: 100%|████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 16.23it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs256_tmp0.2_Miter10_h32_lr3e-4/distance_noRZ_ITI+T_ByT_73/
# pos: -2.8484 neg:  11.4746 total:  8.6262 temperature:  0.2000: 100%|████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 15.55it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs256_tmp0.2_Miter10_h32_lr3e-4/angle_noRZ_ITI+T_ByT+shift0.5_73/
# pos: -2.3715 neg:  11.5628 total:  9.1913 temperature:  0.2000: 100%|████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 14.81it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs256_tmp0.2_Miter10_h32_lr3e-4/distance_noRZ_ITI+T_ByT+shift0.5_73/
# pos: -3.9751 neg:  11.7921 total:  7.8171 temperature:  0.2000: 100%|████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 13.09it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs512_tmp0.5_Miter10_h128_lr3e-4/angle_noRZ_ITI+T_ByT_73/
# already exists at ../../../data/gridsearch_results/demo_YC073_bs512_tmp0.5_Miter10_h128_lr3e-4/angle_noRZ_ITI+T_ByT_73/
# starting ../../../data/gridsearch_results/demo_YC073_bs512_tmp0.5_Miter10_h128_lr3e-4/distance_noRZ_ITI+T_ByT_73/
# already exists at ../../../data/gridsearch_results/demo_YC073_bs512_tmp0.5_Miter10_h128_lr3e-4/distance_noRZ_ITI+T_ByT_73/
# starting ../../../data/gridsearch_results/demo_YC073_bs512_tmp0.5_Miter10_h128_lr3e-4/angle_noRZ_ITI+T_ByT+shift0.5_73/
# already exists at ../../../data/gridsearch_results/demo_YC073_bs512_tmp0.5_Miter10_h128_lr3e-4/angle_noRZ_ITI+T_ByT+shift0.5_73/
# starting ../../../data/gridsearch_results/demo_YC073_bs512_tmp0.5_Miter10_h128_lr3e-4/distance_noRZ_ITI+T_ByT+shift0.5_73/
# already exists at ../../../data/gridsearch_results/demo_YC073_bs512_tmp0.5_Miter10_h128_lr3e-4/distance_noRZ_ITI+T_ByT+shift0.5_73/
# starting ../../../data/gridsearch_results/demo_YC073_bs512_tmp0.2_Miter10_h32_lr3e-4/angle_noRZ_ITI+T_ByT_73/
# already exists at ../../../data/gridsearch_results/demo_YC073_bs512_tmp0.2_Miter10_h32_lr3e-4/angle_noRZ_ITI+T_ByT_73/
# starting ../../../data/gridsearch_results/demo_YC073_bs512_tmp0.2_Miter10_h32_lr3e-4/distance_noRZ_ITI+T_ByT_73/
# already exists at ../../../data/gridsearch_results/demo_YC073_bs512_tmp0.2_Miter10_h32_lr3e-4/distance_noRZ_ITI+T_ByT_73/
# starting ../../../data/gridsearch_results/demo_YC073_bs512_tmp0.2_Miter10_h32_lr3e-4/angle_noRZ_ITI+T_ByT+shift0.5_73/
# already exists at ../../../data/gridsearch_results/demo_YC073_bs512_tmp0.2_Miter10_h32_lr3e-4/angle_noRZ_ITI+T_ByT+shift0.5_73/
# starting ../../../data/gridsearch_results/demo_YC073_bs512_tmp0.2_Miter10_h32_lr3e-4/distance_noRZ_ITI+T_ByT+shift0.5_73/
# already exists at ../../../data/gridsearch_results/demo_YC073_bs512_tmp0.2_Miter10_h32_lr3e-4/distance_noRZ_ITI+T_ByT+shift0.5_73/
# starting ../../../data/gridsearch_results/demo_YC073_bs512_tmp0.5_Miter10_h16_lr3e-4/angle_noRZ_ITI+T_ByT_73/
# already exists at ../../../data/gridsearch_results/demo_YC073_bs512_tmp0.5_Miter10_h16_lr3e-4/angle_noRZ_ITI+T_ByT_73/
# starting ../../../data/gridsearch_results/demo_YC073_bs512_tmp0.5_Miter10_h16_lr3e-4/distance_noRZ_ITI+T_ByT_73/
# already exists at ../../../data/gridsearch_results/demo_YC073_bs512_tmp0.5_Miter10_h16_lr3e-4/distance_noRZ_ITI+T_ByT_73/
# starting ../../../data/gridsearch_results/demo_YC073_bs512_tmp0.5_Miter10_h16_lr3e-4/angle_noRZ_ITI+T_ByT+shift0.5_73/
# already exists at ../../../data/gridsearch_results/demo_YC073_bs512_tmp0.5_Miter10_h16_lr3e-4/angle_noRZ_ITI+T_ByT+shift0.5_73/
# starting ../../../data/gridsearch_results/demo_YC073_bs512_tmp0.5_Miter10_h16_lr3e-4/distance_noRZ_ITI+T_ByT+shift0.5_73/
# already exists at ../../../data/gridsearch_results/demo_YC073_bs512_tmp0.5_Miter10_h16_lr3e-4/distance_noRZ_ITI+T_ByT+shift0.5_73/
# starting ../../../data/gridsearch_results/demo_YC073_bs256_tmp2_Miter10_h16_lr3e-4/angle_noRZ_ITI+T_ByT_73/
# pos: -0.1824 neg:  7.7000 total:  7.5176 temperature:  2.0000: 100%|█████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 13.70it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs256_tmp2_Miter10_h16_lr3e-4/distance_noRZ_ITI+T_ByT_73/
# pos: -0.1944 neg:  7.7082 total:  7.5137 temperature:  2.0000: 100%|█████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 13.75it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs256_tmp2_Miter10_h16_lr3e-4/angle_noRZ_ITI+T_ByT+shift0.5_73/
# pos: -0.2892 neg:  7.7946 total:  7.5053 temperature:  2.0000: 100%|█████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 14.52it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs256_tmp2_Miter10_h16_lr3e-4/distance_noRZ_ITI+T_ByT+shift0.5_73/
# pos: -0.2212 neg:  7.7370 total:  7.5158 temperature:  2.0000: 100%|█████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 14.30it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs256_tmp1.5_Miter10_h64_lr3e-4/angle_noRZ_ITI+T_ByT_73/
# pos: -0.5491 neg:  8.0470 total:  7.4979 temperature:  1.5000: 100%|█████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 14.57it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs256_tmp1.5_Miter10_h64_lr3e-4/distance_noRZ_ITI+T_ByT_73/
# pos: -0.4060 neg:  7.9221 total:  7.5162 temperature:  1.5000: 100%|█████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 14.77it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs256_tmp1.5_Miter10_h64_lr3e-4/angle_noRZ_ITI+T_ByT+shift0.5_73/
# pos: -0.5415 neg:  8.0371 total:  7.4956 temperature:  1.5000: 100%|█████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 16.49it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs256_tmp1.5_Miter10_h64_lr3e-4/distance_noRZ_ITI+T_ByT+shift0.5_73/
# pos: -0.4535 neg:  7.9594 total:  7.5060 temperature:  1.5000: 100%|█████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 14.40it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs1024_tmp0.2_Miter10_h64_lr3e-4/angle_noRZ_ITI+T_ByT_73/
# pos: -4.2479 neg:  13.2998 total:  9.0519 temperature:  0.2000: 100%|████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 12.74it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs1024_tmp0.2_Miter10_h64_lr3e-4/distance_noRZ_ITI+T_ByT_73/
# pos: -4.8220 neg:  13.7151 total:  8.8930 temperature:  0.2000: 100%|████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 14.74it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs1024_tmp0.2_Miter10_h64_lr3e-4/angle_noRZ_ITI+T_ByT+shift0.5_73/
# pos: -4.8457 neg:  13.7288 total:  8.8832 temperature:  0.2000: 100%|████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 14.22it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs1024_tmp0.2_Miter10_h64_lr3e-4/distance_noRZ_ITI+T_ByT+shift0.5_73/
# pos: -4.7121 neg:  13.6262 total:  8.9141 temperature:  0.2000: 100%|████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 15.53it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs256_tmp0.5_Miter10_h64_lr3e-4/angle_noRZ_ITI+T_ByT_73/
# pos: -1.8319 neg:  9.3248 total:  7.4929 temperature:  0.5000: 100%|█████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 14.98it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs256_tmp0.5_Miter10_h64_lr3e-4/distance_noRZ_ITI+T_ByT_73/
# pos: -1.6901 neg:  9.2017 total:  7.5116 temperature:  0.5000: 100%|█████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 16.64it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs256_tmp0.5_Miter10_h64_lr3e-4/angle_noRZ_ITI+T_ByT+shift0.5_73/
# pos: -1.7731 neg:  9.2812 total:  7.5081 temperature:  0.5000: 100%|█████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 16.01it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs256_tmp0.5_Miter10_h64_lr3e-4/distance_noRZ_ITI+T_ByT+shift0.5_73/
# pos: -1.2994 neg:  8.9420 total:  7.6426 temperature:  0.5000: 100%|█████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 13.99it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs512_tmp1_Miter10_h32_lr3e-4/angle_noRZ_ITI+T_ByT_73/
# already exists at ../../../data/gridsearch_results/demo_YC073_bs512_tmp1_Miter10_h32_lr3e-4/angle_noRZ_ITI+T_ByT_73/
# starting ../../../data/gridsearch_results/demo_YC073_bs512_tmp1_Miter10_h32_lr3e-4/distance_noRZ_ITI+T_ByT_73/
# already exists at ../../../data/gridsearch_results/demo_YC073_bs512_tmp1_Miter10_h32_lr3e-4/distance_noRZ_ITI+T_ByT_73/
# starting ../../../data/gridsearch_results/demo_YC073_bs512_tmp1_Miter10_h32_lr3e-4/angle_noRZ_ITI+T_ByT+shift0.5_73/
# already exists at ../../../data/gridsearch_results/demo_YC073_bs512_tmp1_Miter10_h32_lr3e-4/angle_noRZ_ITI+T_ByT+shift0.5_73/
# starting ../../../data/gridsearch_results/demo_YC073_bs512_tmp1_Miter10_h32_lr3e-4/distance_noRZ_ITI+T_ByT+shift0.5_73/
# already exists at ../../../data/gridsearch_results/demo_YC073_bs512_tmp1_Miter10_h32_lr3e-4/distance_noRZ_ITI+T_ByT+shift0.5_73/
# starting ../../../data/gridsearch_results/demo_YC073_bs1024_tmp1_Miter10_h16_lr3e-4/angle_noRZ_ITI+T_ByT_73/
# pos: -0.3497 neg:  9.3187 total:  8.9690 temperature:  1.0000: 100%|█████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 11.62it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs1024_tmp1_Miter10_h16_lr3e-4/distance_noRZ_ITI+T_ByT_73/
# pos: -0.1686 neg:  9.1823 total:  9.0136 temperature:  1.0000: 100%|█████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 13.22it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs1024_tmp1_Miter10_h16_lr3e-4/angle_noRZ_ITI+T_ByT+shift0.5_73/
# pos: -0.4313 neg:  9.3855 total:  8.9542 temperature:  1.0000: 100%|█████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 14.88it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs1024_tmp1_Miter10_h16_lr3e-4/distance_noRZ_ITI+T_ByT+shift0.5_73/
# pos: -0.5272 neg:  9.4684 total:  8.9412 temperature:  1.0000: 100%|█████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 14.20it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs256_tmp2_Miter10_h64_lr3e-4/angle_noRZ_ITI+T_ByT_73/
# pos: -0.3014 neg:  7.8066 total:  7.5052 temperature:  2.0000: 100%|█████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 13.40it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs256_tmp2_Miter10_h64_lr3e-4/distance_noRZ_ITI+T_ByT_73/
# pos: -0.2993 neg:  7.7994 total:  7.5001 temperature:  2.0000: 100%|█████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 15.80it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs256_tmp2_Miter10_h64_lr3e-4/angle_noRZ_ITI+T_ByT+shift0.5_73/
# pos: -0.2406 neg:  7.7475 total:  7.5070 temperature:  2.0000: 100%|█████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 15.76it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs256_tmp2_Miter10_h64_lr3e-4/distance_noRZ_ITI+T_ByT+shift0.5_73/
# pos: -0.3569 neg:  7.8540 total:  7.4971 temperature:  2.0000: 100%|█████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 15.10it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs256_tmp1_Miter10_h64_lr3e-4/angle_noRZ_ITI+T_ByT_73/
# pos: -0.6898 neg:  8.2115 total:  7.5217 temperature:  1.0000: 100%|█████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 13.40it/s]
# starting ../../../data/gridsearch_results/demo_YC073_bs256_tmp1_Miter10_h64_lr3e-4/distance_noRZ_ITI+T_ByT_73/
# pos: -0.6001 neg:  8.1301 total:  7.5300 temperature:  1.0000: 100%|█████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 15.65it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 70
#      68 for approach in ["noRZ_ITI+T_ByT", "noRZ_ITI+T_ByT+shift0.5"]:
#      69     for behavior in ["angle", "distance"]:
# ---> 70         cebra_analysis_helpers.run_single_grid(output_dir,mouse_and_date_list, neural_data_list, conditions_dict_list, indices_of_trials_each_frame_list,
#      71                         m_str, batch_size,time_offset,temperature_mode,temperature,max_iter,num_hidden_units,output_dims,lr,
#      72                         behavior,approach, conditional, test_size,  tmux_session_name = mouse_id, device_id = device_id)
#
# File ~\Desktop\ross\CEBRA-social-foraging-master\Library\python\cebra_analysis_helpers\cebra_analysis_helpers.py:1204, in run_single_grid(output_dir, mouse_and_date_list, neural_data_list, conditions_dict_list, indices_of_trials_each_frame_list, m_str, batch_size, time_offset, temperature_mode, temperature, max_iter, num_hidden_units, output_dims, lr, behavior, approach, conditional, test_size, tmux_session_name, device_id)
#    1201 dump_file = f"{behavior_approach_path}train_valid_dict_{tmux_session_name}.pkl"
#    1203 with open(dump_file, 'wb') as f:
# -> 1204     pickle.dump(train_valid_dict, f)
#
# KeyboardInterrupt:
# Error in callback <function flush_figures at 0x000002D2DB0E85E0> (for post_execute), with arguments args (),kwargs {}:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~\.conda\envs\cebra\Lib\site-packages\matplotlib_inline\backend_inline.py:126, in flush_figures()
#     123 if InlineBackend.instance().close_figures:
#     124     # ignore the tracking, just draw and close all figures
#     125     try:
# --> 126         return show(True)
#     127     except Exception as e:
#     128         # safely show traceback if in IPython, else raise
#     129         ip = get_ipython()
#
# File ~\.conda\envs\cebra\Lib\site-packages\matplotlib_inline\backend_inline.py:90, in show(close, block)
#      88 try:
#      89     for figure_manager in Gcf.get_all_fig_managers():
# ---> 90         display(
#      91             figure_manager.canvas.figure,
#      92             metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      93         )
#      94 finally:
#      95     show._to_draw = []
#
# File ~\.conda\envs\cebra\Lib\site-packages\IPython\core\display_functions.py:278, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     276     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     277 else:
# --> 278     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     279     if not format_dict:
#     280         # nothing to display (e.g. _ipython_display_ took over)
#     281         continue
#
# File ~\.conda\envs\cebra\Lib\site-packages\IPython\core\formatters.py:238, in DisplayFormatter.format(self, obj, include, exclude)
#     236 md = None
#     237 try:
# --> 238     data = formatter(obj)
#     239 except:
#     240     # FIXME: log the exception
#     241     raise
#
# File <decorator-gen-16>:2, in __call__(self, obj)
#
# File ~\.conda\envs\cebra\Lib\site-packages\IPython\core\formatters.py:282, in catch_format_error(method, self, *args, **kwargs)
#     280 """show traceback on failed format call"""
#     281 try:
# --> 282     r = method(self, *args, **kwargs)
#     283 except NotImplementedError:
#     284     # don't warn on NotImplementedErrors
#     285     return self._check_return(None, args[0])
#
# File ~\.conda\envs\cebra\Lib\site-packages\IPython\core\formatters.py:402, in BaseFormatter.__call__(self, obj)
#     400     pass
#     401 else:
# --> 402     return printer(obj)
#     403 # Finally look for special method names
#     404 method = get_real_method(obj, self.print_method)
#
# File ~\.conda\envs\cebra\Lib\site-packages\IPython\core\pylabtools.py:170, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     167     from matplotlib.backend_bases import FigureCanvasBase
#     168     FigureCanvasBase(fig)
# --> 170 fig.canvas.print_figure(bytes_io, **kw)
#     171 data = bytes_io.getvalue()
#     172 if fmt == 'svg':
#
# File ~\.conda\envs\cebra\Lib\site-packages\matplotlib\backend_bases.py:2158, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2156 if bbox_inches:
#    2157     if bbox_inches == "tight":
# -> 2158         bbox_inches = self.figure.get_tightbbox(
#    2159             renderer, bbox_extra_artists=bbox_extra_artists)
#    2160         if (isinstance(layout_engine, ConstrainedLayoutEngine) and
#    2161                 pad_inches == "layout"):
#    2162             h_pad = layout_engine.get()["h_pad"]
#
# File ~\.conda\envs\cebra\Lib\site-packages\matplotlib\figure.py:1848, in FigureBase.get_tightbbox(self, renderer, bbox_extra_artists)
#    1844 if ax.get_visible():
#    1845     # some Axes don't take the bbox_extra_artists kwarg so we
#    1846     # need this conditional....
#    1847     try:
# -> 1848         bbox = ax.get_tightbbox(
#    1849             renderer, bbox_extra_artists=bbox_extra_artists)
#    1850     except TypeError:
#    1851         bbox = ax.get_tightbbox(renderer)
#
# File ~\.conda\envs\cebra\Lib\site-packages\matplotlib\axes\_base.py:4554, in _AxesBase.get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists, for_layout_only)
#    4552 for axis in self._axis_map.values():
#    4553     if self.axison and axis.get_visible():
# -> 4554         ba = martist._get_tightbbox_for_layout_only(axis, renderer)
#    4555         if ba:
#    4556             bb.append(ba)
#
# File ~\.conda\envs\cebra\Lib\site-packages\matplotlib\artist.py:1402, in _get_tightbbox_for_layout_only(obj, *args, **kwargs)
#    1396 """
#    1397 Matplotlib's `.Axes.get_tightbbox` and `.Axis.get_tightbbox` support a
#    1398 *for_layout_only* kwarg; this helper tries to use the kwarg but skips it
#    1399 when encountering third-party subclasses that do not support it.
#    1400 """
#    1401 try:
# -> 1402     return obj.get_tightbbox(*args, **{**kwargs, "for_layout_only": True})
#    1403 except TypeError:
#    1404     return obj.get_tightbbox(*args, **kwargs)
#
# File ~\.conda\envs\cebra\Lib\site-packages\matplotlib\axis.py:1353, in Axis.get_tightbbox(self, renderer, for_layout_only)
#    1350     renderer = self.get_figure(root=True)._get_renderer()
#    1351 ticks_to_draw = self._update_ticks()
# -> 1353 self._update_label_position(renderer)
#    1355 # go back to just this axis's tick labels
#    1356 tlb1, tlb2 = self._get_ticklabel_bboxes(ticks_to_draw, renderer)
#
# File ~\.conda\envs\cebra\Lib\site-packages\matplotlib\axis.py:2454, in XAxis._update_label_position(self, renderer)
#    2449 x, y = self.label.get_position()
#    2451 if self.label_position == 'bottom':
#    2452     # Union with extents of the bottom spine if present, of the axes otherwise.
#    2453     bbox = mtransforms.Bbox.union([
# -> 2454         *bboxes, self.axes.spines.get("bottom", self.axes).get_window_extent()])
#    2455     self.label.set_position(
#    2456         (x, bbox.y0 - self.labelpad * self.get_figure(root=True).dpi / 72))
#    2457 else:
#    2458     # Union with extents of the top spine if present, of the axes otherwise.
#
# File ~\.conda\envs\cebra\Lib\site-packages\matplotlib\spines.py:158, in Spine.get_window_extent(self, renderer)
#     156     return bb
#     157 bboxes = [bb]
# --> 158 drawn_ticks = self.axis._update_ticks()
#     160 major_tick = next(iter({*drawn_ticks} & {*self.axis.majorTicks}), None)
#     161 minor_tick = next(iter({*drawn_ticks} & {*self.axis.minorTicks}), None)
#
# File ~\.conda\envs\cebra\Lib\site-packages\matplotlib\axis.py:1288, in Axis._update_ticks(self)
#    1286     tick.label1.set_text(label)
#    1287     tick.label2.set_text(label)
# -> 1288 minor_locs = self.get_minorticklocs()
#    1289 minor_labels = self.minor.formatter.format_ticks(minor_locs)
#    1290 minor_ticks = self.get_minor_ticks(len(minor_locs))
#
# File ~\.conda\envs\cebra\Lib\site-packages\matplotlib\axis.py:1532, in Axis.get_minorticklocs(self)
#    1530 minor_locs = np.asarray(self.minor.locator())
#    1531 if self.remove_overlapping_locs:
# -> 1532     major_locs = self.major.locator()
#    1533     transform = self._scale.get_transform()
#    1534     tr_minor_locs = transform.transform(minor_locs)
#
# File ~\.conda\envs\cebra\Lib\site-packages\matplotlib\ticker.py:2230, in MaxNLocator.__call__(self)
#    2228 def __call__(self):
#    2229     vmin, vmax = self.axis.get_view_interval()
# -> 2230     return self.tick_values(vmin, vmax)
#
# File ~\.conda\envs\cebra\Lib\site-packages\matplotlib\ticker.py:2238, in MaxNLocator.tick_values(self, vmin, vmax)
#    2235     vmin = -vmax
#    2236 vmin, vmax = mtransforms.nonsingular(
#    2237     vmin, vmax, expander=1e-13, tiny=1e-14)
# -> 2238 locs = self._raw_ticks(vmin, vmax)
#    2240 prune = self._prune
#    2241 if prune == 'lower':
#
# File ~\.conda\envs\cebra\Lib\site-packages\matplotlib\ticker.py:2168, in MaxNLocator._raw_ticks(self, vmin, vmax)
#    2166 if self._nbins == 'auto':
#    2167     if self.axis is not None:
# -> 2168         nbins = np.clip(self.axis.get_tick_space(),
#    2169                         max(1, self._min_n_ticks - 1), 9)
#    2170     else:
#    2171         nbins = 9
#
# File ~\.conda\envs\cebra\Lib\site-packages\matplotlib\axis.py:2581, in XAxis.get_tick_space(self)
#    2580 def get_tick_space(self):
# -> 2581     ends = mtransforms.Bbox.unit().transformed(
#    2582         self.axes.transAxes - self.get_figure(root=False).dpi_scale_trans)
#    2583     length = ends.width * 72
#    2584     # There is a heuristic here that the aspect ratio of tick text
#    2585     # is no more than 3:1
#
# File ~\.conda\envs\cebra\Lib\site-packages\matplotlib\transforms.py:465, in BboxBase.transformed(self, transform)
#     461 """
#     462 Construct a `Bbox` by statically transforming this one by *transform*.
#     463 """
#     464 pts = self.get_points()
# --> 465 ll, ul, lr = transform.transform(np.array(
#     466     [pts[0], [pts[0, 0], pts[1, 1]], [pts[1, 0], pts[0, 1]]]))
#     467 return Bbox([ll, [lr[0], ul[1]]])
#
# File ~\.conda\envs\cebra\Lib\site-packages\matplotlib\transforms.py:1495, in Transform.transform(self, values)
#    1492 values = values.reshape((-1, self.input_dims))
#    1494 # Transform the values
# -> 1495 res = self.transform_affine(self.transform_non_affine(values))
#    1497 # Convert the result back to the shape of the input values.
#    1498 if ndim == 0:
#
# File ~\.conda\envs\cebra\Lib\site-packages\matplotlib\transforms.py:2410, in CompositeGenericTransform.transform_affine(self, values)
#    2408 def transform_affine(self, values):
#    2409     # docstring inherited
# -> 2410     return self.get_affine().transform(values)
#
# File ~\.conda\envs\cebra\Lib\site-packages\matplotlib\transforms.py:2436, in CompositeGenericTransform.get_affine(self)
#    2434     return self._b.get_affine()
#    2435 else:
# -> 2436     return Affine2D(np.dot(self._b.get_affine().get_matrix(),
#    2437                            self._a.get_affine().get_matrix()))
#
# KeyboardInterrupt:
